# %% [markdown]
# # 環境変数の設定（1~3共有）

# %% [markdown]
# GitHubから演習用のコードをCloneします。

# %%
# !git clone https://github.com/matsuolab/lecture-ai-engineering.git
# Out:
# Cloning into 'lecture-ai-engineering'...
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 41 (delta 7), reused 5 (delta 5), pack-reused 13 (from 1)
# Receiving objects: 100% (41/41), 34.04 KiB | 580.00 KiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %% [markdown]
# 必要なAPIトークンを.envに設定します。
#
# 「lecture-ai-engineering/day1」の配下に、「.env_template」ファイルが存在しています。
#
# 隠しファイルのため表示されていない場合は、画面左側のある、目のアイコンの「隠しファイルの表示」ボタンを押してください。
#
# 「.env_template」のファイル名を「.env」に変更します。「.env」ファイルを開くと、以下のような中身になっています。
#
#
# ```
# HUGGINGFACE_TOKEN="hf-********"
# NGROK_TOKEN="********"
# ```
# ダブルクオーテーションで囲まれた文字列をHuggingfaceのアクセストークンと、ngrokの認証トークンで書き変えてください。
#
# それぞれのアカウントが作成済みであれば、以下のURLからそれぞれのトークンを取得できます。
#
# - Huggingfaceのアクセストークン
# https://huggingface.co/docs/hub/security-tokens
#
# - ngrokの認証トークン
# https://dashboard.ngrok.com/get-started/your-authtoken
#
# 書き換えたら、「.env」ファイルをローカルのPCにダウンロードしてください。
#
# 「01_streamlit_UI」から「02_streamlit_app」へ進む際に、CPUからGPUの利用に切り替えるため、セッションが一度切れてしまいます。
#
# その際に、トークンを設定した「.env」ファイルは再作成することになるので、その手間を減らすために「.env」ファイルをダウンロードしておくと良いです。

# %% [markdown]
# 「.env」ファイルを読み込み、環境変数として設定します。次のセルを実行し、最終的に「True」が表示されていればうまく読み込めています。

# %%
# !pip install python-dotenv
from dotenv import load_dotenv, find_dotenv

# %cd /content/lecture-ai-engineering/day1
load_dotenv(find_dotenv())
# Out:
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (1.1.0)
# /content/lecture-ai-engineering/day1
# True

# %% [markdown]
# # <font color="red">変更点</font>
# <font color="red">config.py: gemma-2-2b-jpn-it -> google/gemma-3-4b-it</font>
#
# <font color="red">ui.py, app.py: prompt に対する応答スタイルを追加、ヒントを追加</font>

# %% [markdown]
# # 02_streamlit_app

# %% [markdown]
# ディレクトリ「02_streamlit_app」に移動します。

# %%
# %cd /content/lecture-ai-engineering/day1/02_streamlit_app
# Out:
# /content/lecture-ai-engineering/day1/02_streamlit_app

# %% [markdown]
# 必要なライブラリをインストールします。

# %%
# %%capture
# !pip install -r requirements.txt

# %% [markdown]
# ngrokとhuggigfaceのトークンを使用して、認証を行います。

# %%
# !ngrok authtoken $$NGROK_TOKEN
# !huggingface-cli login --token $$HUGGINGFACE_TOKEN
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# The token `galaxy` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `galaxy`

# %% [markdown]
# stramlitでHuggingfaceのトークン情報を扱うために、streamlit用の設定ファイル（.streamlit）を作成し、トークンの情報を格納します。

# %%
# .streamlit/secrets.toml ファイルを作成
import os
import toml

# 設定ファイルのディレクトリ確保
os.makedirs('.streamlit', exist_ok=True)

# 環境変数から取得したトークンを設定ファイルに書き込む
secrets = {
    "huggingface": {
        "token": os.environ.get("HUGGINGFACE_TOKEN", "")
    }
}

# 設定ファイルを書き込む
with open('.streamlit/secrets.toml', 'w') as f:
    toml.dump(secrets, f)

# %% [markdown]
# アプリを起動します。
#
# 02_streamlit_appでは、Huggingfaceからモデルをダウンロードするため、初回起動には2分程度時間がかかります。
#
# この待ち時間を利用して、app.pyのコードを確認してみましょう。

# %%
from pyngrok import ngrok

public_url = ngrok.connect(8501).public_url
print(f"公開URL: {public_url}")
# !streamlit run app.py
# Out:
# 公開URL: https://86ec-34-125-159-251.ngrok-free.app
#
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.125.159.251:8501
#
# NLTK loaded successfully.
# 2025-04-21 17:49:02.212501: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745257742.446762    2230 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745257742.510516    2230 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-21 17:49:02.995219: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# NLTK Punkt data checked/downloaded.
# Database 'chat_feedback.db' initialized successfully.
# Data saved to DB successfully.
# Data saved to DB successfully.
# Data saved to DB successfully.
# Data saved to DB successfully.
# Data saved to DB successfully.
# Data saved to DB successfully.
# Data saved to DB successfully.
# Data saved to DB successfully.
# Data saved to DB successfully.
# Data saved to DB successfully.
# config.json: 100% 855/855 [00:00<00:00, 4.78MB/s]
# model.safetensors.index.json: 100% 90.6k/90.6k [00:00<00:00, 1.32MB/s]
# Fetching 2 files:   0% 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0% 0.00/3.64G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   1% 21.0M/3.64G [00:00<00:22, 159MB/s]
# model-00002-of-00002.safetensors:   1% 52.4M/3.64G [00:00<00:15, 237MB/s]
# model-00002-of-00002.safetensors:   2% 83.9M/3.64G [00:00<00:13, 263MB/s]
# model-00002-of-00002.safetensors:   3% 115M/3.64G [00:00<00:12, 280MB/s]
# model-00002-of-00002.safetensors:   4% 147M/3.64G [00:00<00:13, 267MB/s]
#
# model-00001-of-00002.safetensors:   0% 0.00/4.96G [00:00<?, ?B/s]
#
# model-00001-of-00002.safetensors:   0% 10.5M/4.96G [00:00<00:49, 99.2MB/s]
# model-00002-of-00002.safetensors:   5% 178M/3.64G [00:00<00:13, 248MB/s]
#
# model-00001-of-00002.safetensors:   1% 31.5M/4.96G [00:00<00:31, 159MB/s]
# model-00002-of-00002.safetensors:   6% 210M/3.64G [00:00<00:15, 225MB/s]
#
# model-00001-of-00002.safetensors:   1% 52.4M/4.96G [00:00<00:27, 178MB/s]
# model-00002-of-00002.safetensors:   7% 241M/3.64G [00:01<00:15, 225MB/s]
#
# model-00001-of-00002.safetensors:   2% 83.9M/4.96G [00:00<00:25, 194MB/s]
# model-00002-of-00002.safetensors:   7% 273M/3.64G [00:01<00:15, 219MB/s]
#
# model-00001-of-00002.safetensors:   2% 115M/4.96G [00:00<00:23, 203MB/s]
#
# model-00001-of-00002.safetensors:   3% 136M/4.96G [00:00<00:25, 187MB/s]
# model-00002-of-00002.safetensors:   8% 304M/3.64G [00:01<00:16, 198MB/s]
#
# model-00001-of-00002.safetensors:   3% 157M/4.96G [00:00<00:33, 146MB/s]
# model-00002-of-00002.safetensors:   9% 325M/3.64G [00:01<00:22, 149MB/s]
#
# model-00001-of-00002.safetensors:   4% 178M/4.96G [00:01<00:35, 135MB/s]
# model-00002-of-00002.safetensors:  10% 346M/3.64G [00:01<00:22, 146MB/s]
#
# model-00001-of-00002.safetensors:   4% 199M/4.96G [00:01<00:34, 139MB/s]
# model-00002-of-00002.safetensors:  10% 367M/3.64G [00:01<00:21, 152MB/s]
#
# model-00001-of-00002.safetensors:   4% 220M/4.96G [00:01<00:34, 136MB/s]
# model-00002-of-00002.safetensors:  11% 388M/3.64G [00:02<00:22, 147MB/s]
#
# model-00001-of-00002.safetensors:   5% 241M/4.96G [00:01<00:33, 139MB/s]
# model-00002-of-00002.safetensors:  11% 409M/3.64G [00:02<00:23, 136MB/s]
#
# model-00001-of-00002.safetensors:   5% 262M/4.96G [00:01<00:36, 130MB/s]
# model-00002-of-00002.safetensors:  12% 430M/3.64G [00:02<00:28, 111MB/s]
#
# model-00001-of-00002.safetensors:   6% 283M/4.96G [00:01<00:39, 118MB/s]
# model-00002-of-00002.safetensors:  12% 451M/3.64G [00:02<00:30, 106MB/s]
#
# model-00001-of-00002.safetensors:   6% 304M/4.96G [00:02<00:39, 119MB/s]
# model-00002-of-00002.safetensors:  13% 472M/3.64G [00:02<00:26, 121MB/s]
#
# model-00001-of-00002.safetensors:   7% 325M/4.96G [00:02<00:34, 134MB/s]
# model-00002-of-00002.safetensors:  14% 493M/3.64G [00:02<00:23, 135MB/s]
#
# model-00001-of-00002.safetensors:   7% 346M/4.96G [00:02<00:32, 141MB/s]
# model-00002-of-00002.safetensors:  14% 514M/3.64G [00:03<00:21, 145MB/s]
#
# model-00001-of-00002.safetensors:   7% 367M/4.96G [00:02<00:32, 140MB/s]
# model-00002-of-00002.safetensors:  15% 535M/3.64G [00:03<00:22, 137MB/s]
#
# model-00001-of-00002.safetensors:   8% 388M/4.96G [00:02<00:33, 136MB/s]
# model-00002-of-00002.safetensors:  15% 556M/3.64G [00:03<00:28, 110MB/s]
#
# model-00001-of-00002.safetensors:   8% 409M/4.96G [00:02<00:39, 114MB/s]
# model-00002-of-00002.safetensors:  16% 577M/3.64G [00:03<00:26, 115MB/s]
#
# model-00001-of-00002.safetensors:   9% 430M/4.96G [00:03<00:37, 122MB/s]
#
# model-00001-of-00002.safetensors:   9% 451M/4.96G [00:03<00:32, 137MB/s]
# model-00002-of-00002.safetensors:  16% 598M/3.64G [00:03<00:24, 126MB/s]
#
# model-00001-of-00002.safetensors:  10% 472M/4.96G [00:03<00:33, 133MB/s]
# model-00002-of-00002.safetensors:  17% 619M/3.64G [00:03<00:23, 127MB/s]
# model-00002-of-00002.safetensors:  18% 640M/3.64G [00:04<00:21, 142MB/s]
#
# model-00001-of-00002.safetensors:  10% 493M/4.96G [00:03<00:34, 128MB/s]
# model-00002-of-00002.safetensors:  18% 661M/3.64G [00:04<00:23, 128MB/s]
#
# model-00001-of-00002.safetensors:  10% 514M/4.96G [00:03<00:36, 121MB/s]
# model-00002-of-00002.safetensors:  19% 682M/3.64G [00:04<00:25, 114MB/s]
#
# model-00001-of-00002.safetensors:  11% 535M/4.96G [00:04<00:40, 108MB/s]
# model-00002-of-00002.safetensors:  19% 703M/3.64G [00:04<00:28, 103MB/s]
#
# model-00001-of-00002.safetensors:  11% 556M/4.96G [00:04<00:42, 102MB/s]
# model-00002-of-00002.safetensors:  20% 724M/3.64G [00:04<00:28, 101MB/s]
#
# model-00001-of-00002.safetensors:  12% 577M/4.96G [00:04<00:43, 101MB/s]
# model-00002-of-00002.safetensors:  20% 744M/3.64G [00:05<00:27, 107MB/s]
#
# model-00001-of-00002.safetensors:  12% 598M/4.96G [00:04<00:39, 111MB/s]
# model-00002-of-00002.safetensors:  21% 765M/3.64G [00:05<00:24, 119MB/s]
#
# model-00001-of-00002.safetensors:  12% 619M/4.96G [00:04<00:37, 116MB/s]
# model-00002-of-00002.safetensors:  22% 786M/3.64G [00:05<00:22, 125MB/s]
#
# model-00001-of-00002.safetensors:  13% 640M/4.96G [00:04<00:34, 124MB/s]
# model-00002-of-00002.safetensors:  22% 807M/3.64G [00:05<00:22, 127MB/s]
#
# model-00001-of-00002.safetensors:  13% 661M/4.96G [00:05<00:34, 125MB/s]
# model-00002-of-00002.safetensors:  23% 828M/3.64G [00:05<00:22, 124MB/s]
#
# model-00001-of-00002.safetensors:  14% 682M/4.96G [00:05<00:35, 120MB/s]
# model-00002-of-00002.safetensors:  23% 849M/3.64G [00:05<00:21, 130MB/s]
#
# model-00001-of-00002.safetensors:  14% 703M/4.96G [00:05<00:34, 125MB/s]
# model-00002-of-00002.safetensors:  24% 870M/3.64G [00:06<00:20, 137MB/s]
#
# model-00001-of-00002.safetensors:  15% 724M/4.96G [00:05<00:31, 133MB/s]
# model-00002-of-00002.safetensors:  24% 891M/3.64G [00:06<00:19, 143MB/s]
#
# model-00001-of-00002.safetensors:  15% 744M/4.96G [00:05<00:30, 138MB/s]
# model-00002-of-00002.safetensors:  25% 912M/3.64G [00:06<00:18, 147MB/s]
#
# model-00001-of-00002.safetensors:  15% 765M/4.96G [00:05<00:29, 144MB/s]
# model-00002-of-00002.safetensors:  26% 933M/3.64G [00:06<00:19, 140MB/s]
#
# model-00001-of-00002.safetensors:  16% 786M/4.96G [00:05<00:29, 142MB/s]
# model-00002-of-00002.safetensors:  26% 954M/3.64G [00:06<00:19, 136MB/s]
#
# model-00001-of-00002.safetensors:  16% 807M/4.96G [00:06<00:30, 137MB/s]
# model-00002-of-00002.safetensors:  27% 975M/3.64G [00:06<00:18, 140MB/s]
#
# model-00001-of-00002.safetensors:  17% 828M/4.96G [00:06<01:01, 66.8MB/s]
#
# model-00001-of-00002.safetensors:  17% 849M/4.96G [00:08<02:12, 31.1MB/s]
# model-00002-of-00002.safetensors:  27% 996M/3.64G [00:08<01:34, 28.1MB/s]
#
# model-00001-of-00002.safetensors:  18% 881M/4.96G [00:08<01:26, 47.4MB/s]
# model-00002-of-00002.safetensors:  28% 1.03G/3.64G [00:09<01:00, 42.9MB/s]
#
# model-00001-of-00002.safetensors:  18% 902M/4.96G [00:08<01:09, 58.7MB/s]
# model-00002-of-00002.safetensors:  29% 1.05G/3.64G [00:09<00:48, 53.1MB/s]
#
# model-00001-of-00002.safetensors:  19% 923M/4.96G [00:08<00:57, 70.2MB/s]
# model-00002-of-00002.safetensors:  29% 1.07G/3.64G [00:09<00:39, 65.8MB/s]
# model-00002-of-00002.safetensors:  30% 1.09G/3.64G [00:09<00:31, 80.9MB/s]
#
# model-00001-of-00002.safetensors:  19% 944M/4.96G [00:08<00:47, 84.1MB/s]
# model-00002-of-00002.safetensors:  31% 1.11G/3.64G [00:09<00:26, 94.8MB/s]
#
# model-00001-of-00002.safetensors:  20% 975M/4.96G [00:09<00:36, 110MB/s]
#
# model-00001-of-00002.safetensors:  20% 996M/4.96G [00:09<00:31, 125MB/s]
# model-00002-of-00002.safetensors:  31% 1.14G/3.64G [00:09<00:21, 119MB/s]
#
# model-00001-of-00002.safetensors:  21% 1.02G/4.96G [00:09<00:28, 136MB/s]
# model-00002-of-00002.safetensors:  32% 1.16G/3.64G [00:09<00:19, 125MB/s]
#
# model-00001-of-00002.safetensors:  21% 1.04G/4.96G [00:09<00:26, 149MB/s]
# model-00002-of-00002.safetensors:  33% 1.18G/3.64G [00:10<00:18, 131MB/s]
# model-00002-of-00002.safetensors:  33% 1.21G/3.64G [00:10<00:17, 142MB/s]
#
# model-00001-of-00002.safetensors:  21% 1.06G/4.96G [00:09<00:29, 131MB/s]
#
# model-00001-of-00002.safetensors:  22% 1.08G/4.96G [00:09<00:27, 139MB/s]
#
# model-00001-of-00002.safetensors:  22% 1.11G/4.96G [00:09<00:23, 165MB/s]
# model-00002-of-00002.safetensors:  34% 1.23G/3.64G [00:10<00:23, 102MB/s]
#
# model-00001-of-00002.safetensors:  23% 1.13G/4.96G [00:09<00:22, 167MB/s]
# model-00002-of-00002.safetensors:  34% 1.25G/3.64G [00:10<00:23, 103MB/s]
#
# model-00001-of-00002.safetensors:  23% 1.15G/4.96G [00:10<00:25, 148MB/s]
# model-00002-of-00002.safetensors:  35% 1.27G/3.64G [00:10<00:21, 112MB/s]
#
# model-00001-of-00002.safetensors:  24% 1.17G/4.96G [00:10<00:26, 142MB/s]
# model-00002-of-00002.safetensors:  35% 1.29G/3.64G [00:12<01:26, 27.2MB/s]
#
# model-00001-of-00002.safetensors:  24% 1.20G/4.96G [00:12<02:08, 29.2MB/s]
#
# model-00001-of-00002.safetensors:  25% 1.23G/4.96G [00:12<01:24, 44.4MB/s]
# model-00002-of-00002.safetensors:  36% 1.32G/3.64G [00:13<00:56, 41.3MB/s]
#
# model-00001-of-00002.safetensors:  25% 1.25G/4.96G [00:12<01:06, 56.1MB/s]
# model-00002-of-00002.safetensors:  37% 1.34G/3.64G [00:13<00:44, 51.9MB/s]
#
# model-00001-of-00002.safetensors:  26% 1.27G/4.96G [00:12<00:54, 67.9MB/s]
# model-00002-of-00002.safetensors:  37% 1.36G/3.64G [00:13<00:35, 63.8MB/s]
#
# model-00001-of-00002.safetensors:  26% 1.29G/4.96G [00:12<00:43, 83.8MB/s]
# model-00002-of-00002.safetensors:  38% 1.38G/3.64G [00:13<00:28, 78.6MB/s]
#
# model-00001-of-00002.safetensors:  26% 1.31G/4.96G [00:13<00:50, 72.1MB/s]
# model-00002-of-00002.safetensors:  39% 1.41G/3.64G [00:13<00:31, 70.3MB/s]
#
# model-00001-of-00002.safetensors:  27% 1.33G/4.96G [00:13<00:41, 86.6MB/s]
# model-00002-of-00002.safetensors:  39% 1.43G/3.64G [00:14<00:26, 82.9MB/s]
#
# model-00001-of-00002.safetensors:  27% 1.35G/4.96G [00:13<00:37, 95.1MB/s]
# model-00002-of-00002.safetensors:  40% 1.45G/3.64G [00:14<00:24, 90.1MB/s]
#
# model-00001-of-00002.safetensors:  28% 1.37G/4.96G [00:13<00:35, 101MB/s]
# model-00002-of-00002.safetensors:  40% 1.47G/3.64G [00:14<00:21, 102MB/s]
#
# model-00001-of-00002.safetensors:  28% 1.39G/4.96G [00:13<00:32, 109MB/s]
# model-00002-of-00002.safetensors:  41% 1.49G/3.64G [00:14<00:21, 98.4MB/s]
# model-00002-of-00002.safetensors:  41% 1.51G/3.64G [00:14<00:18, 114MB/s]
# model-00002-of-00002.safetensors:  42% 1.54G/3.64G [00:14<00:14, 144MB/s]
#
# model-00001-of-00002.safetensors:  29% 1.42G/4.96G [00:14<00:43, 82.2MB/s]
# model-00002-of-00002.safetensors:  43% 1.57G/3.64G [00:14<00:13, 158MB/s]
#
# model-00001-of-00002.safetensors:  29% 1.44G/4.96G [00:14<00:53, 65.6MB/s]
#
# model-00001-of-00002.safetensors:  29% 1.45G/4.96G [00:16<02:27, 23.8MB/s]
# model-00002-of-00002.safetensors:  44% 1.59G/3.64G [00:17<01:02, 32.7MB/s]
#
# model-00001-of-00002.safetensors:  30% 1.48G/4.96G [00:16<01:28, 39.2MB/s]
# model-00002-of-00002.safetensors:  45% 1.63G/3.64G [00:17<00:42, 47.2MB/s]
#
# model-00001-of-00002.safetensors:  30% 1.51G/4.96G [00:16<01:00, 56.9MB/s]
# model-00002-of-00002.safetensors:  46% 1.66G/3.64G [00:17<00:31, 63.7MB/s]
#
# model-00001-of-00002.safetensors:  31% 1.53G/4.96G [00:16<00:49, 69.8MB/s]
# model-00002-of-00002.safetensors:  46% 1.68G/3.64G [00:17<00:25, 75.7MB/s]
#
# model-00001-of-00002.safetensors:  31% 1.55G/4.96G [00:17<00:42, 81.1MB/s]
# model-00002-of-00002.safetensors:  47% 1.70G/3.64G [00:17<00:23, 84.3MB/s]
#
# model-00001-of-00002.safetensors:  32% 1.57G/4.96G [00:17<00:37, 91.1MB/s]
# model-00002-of-00002.safetensors:  47% 1.72G/3.64G [00:17<00:20, 94.0MB/s]
#
# model-00001-of-00002.safetensors:  32% 1.59G/4.96G [00:17<00:33, 99.6MB/s]
# model-00002-of-00002.safetensors:  48% 1.74G/3.64G [00:17<00:18, 103MB/s]
#
# model-00001-of-00002.safetensors:  33% 1.61G/4.96G [00:17<00:29, 112MB/s]
# model-00002-of-00002.safetensors:  48% 1.76G/3.64G [00:18<00:16, 112MB/s]
#
# model-00001-of-00002.safetensors:  33% 1.64G/4.96G [00:17<00:27, 122MB/s]
# model-00002-of-00002.safetensors:  49% 1.78G/3.64G [00:18<00:15, 120MB/s]
#
# model-00001-of-00002.safetensors:  33% 1.66G/4.96G [00:17<00:25, 131MB/s]
# model-00002-of-00002.safetensors:  50% 1.80G/3.64G [00:18<00:14, 125MB/s]
#
# model-00001-of-00002.safetensors:  34% 1.68G/4.96G [00:17<00:23, 140MB/s]
# model-00002-of-00002.safetensors:  50% 1.82G/3.64G [00:18<00:13, 133MB/s]
#
# model-00001-of-00002.safetensors:  34% 1.70G/4.96G [00:18<00:23, 139MB/s]
# model-00002-of-00002.safetensors:  51% 1.85G/3.64G [00:18<00:12, 140MB/s]
#
# model-00001-of-00002.safetensors:  35% 1.72G/4.96G [00:18<00:23, 138MB/s]
# model-00002-of-00002.safetensors:  51% 1.87G/3.64G [00:18<00:12, 142MB/s]
#
# model-00001-of-00002.safetensors:  35% 1.74G/4.96G [00:18<00:23, 135MB/s]
# model-00002-of-00002.safetensors:  52% 1.89G/3.64G [00:18<00:12, 140MB/s]
#
# model-00001-of-00002.safetensors:  36% 1.76G/4.96G [00:18<00:22, 140MB/s]
# model-00002-of-00002.safetensors:  52% 1.91G/3.64G [00:19<00:12, 135MB/s]
#
# model-00001-of-00002.safetensors:  36% 1.78G/4.96G [00:18<00:23, 135MB/s]
# model-00002-of-00002.safetensors:  53% 1.93G/3.64G [00:19<00:15, 112MB/s]
#
# model-00001-of-00002.safetensors:  36% 1.80G/4.96G [00:19<00:36, 87.4MB/s]
# model-00002-of-00002.safetensors:  54% 1.95G/3.64G [00:20<00:25, 65.2MB/s]
#
# model-00001-of-00002.safetensors:  37% 1.82G/4.96G [00:19<00:54, 57.3MB/s]
# model-00002-of-00002.safetensors:  54% 1.96G/3.64G [00:20<00:30, 54.6MB/s]
#
# model-00001-of-00002.safetensors:  37% 1.84G/4.96G [00:20<01:06, 47.3MB/s]
# model-00002-of-00002.safetensors:  54% 1.97G/3.64G [00:20<00:37, 43.9MB/s]
#
# model-00001-of-00002.safetensors:  37% 1.85G/4.96G [00:20<01:18, 39.9MB/s]
# model-00002-of-00002.safetensors:  54% 1.98G/3.64G [00:21<00:42, 39.1MB/s]
# model-00002-of-00002.safetensors:  55% 2.01G/3.64G [00:21<00:25, 64.4MB/s]
#
# model-00001-of-00002.safetensors:  38% 1.88G/4.96G [00:20<00:51, 60.2MB/s]
# model-00002-of-00002.safetensors:  56% 2.03G/3.64G [00:21<00:19, 81.9MB/s]
#
# model-00001-of-00002.safetensors:  38% 1.90G/4.96G [00:20<00:41, 73.6MB/s]
# model-00002-of-00002.safetensors:  56% 2.06G/3.64G [00:21<00:15, 100MB/s]
#
# model-00001-of-00002.safetensors:  39% 1.92G/4.96G [00:21<00:33, 90.2MB/s]
# model-00002-of-00002.safetensors:  57% 2.08G/3.64G [00:21<00:13, 117MB/s]
#
# model-00001-of-00002.safetensors:  39% 1.94G/4.96G [00:21<00:27, 109MB/s]
# model-00002-of-00002.safetensors:  58% 2.10G/3.64G [00:21<00:11, 132MB/s]
#
# model-00001-of-00002.safetensors:  40% 1.96G/4.96G [00:21<00:24, 124MB/s]
# model-00002-of-00002.safetensors:  58% 2.12G/3.64G [00:21<00:10, 148MB/s]
#
# model-00001-of-00002.safetensors:  40% 1.98G/4.96G [00:21<00:21, 141MB/s]
# model-00002-of-00002.safetensors:  59% 2.14G/3.64G [00:21<00:09, 155MB/s]
#
# model-00001-of-00002.safetensors:  41% 2.01G/4.96G [00:21<00:19, 154MB/s]
# model-00002-of-00002.safetensors:  59% 2.16G/3.64G [00:22<00:09, 155MB/s]
# model-00002-of-00002.safetensors:  60% 2.18G/3.64G [00:22<00:09, 152MB/s]
#
# model-00001-of-00002.safetensors:  41% 2.03G/4.96G [00:21<00:21, 134MB/s]
#
# model-00001-of-00002.safetensors:  41% 2.06G/4.96G [00:21<00:20, 142MB/s]
# model-00002-of-00002.safetensors:  61% 2.20G/3.64G [00:22<00:10, 134MB/s]
#
# model-00001-of-00002.safetensors:  42% 2.08G/4.96G [00:22<00:20, 142MB/s]
# model-00002-of-00002.safetensors:  61% 2.22G/3.64G [00:22<00:10, 132MB/s]
#
# model-00001-of-00002.safetensors:  42% 2.10G/4.96G [00:22<00:20, 140MB/s]
# model-00002-of-00002.safetensors:  62% 2.24G/3.64G [00:22<00:11, 126MB/s]
#
# model-00001-of-00002.safetensors:  43% 2.12G/4.96G [00:22<00:21, 132MB/s]
# model-00002-of-00002.safetensors:  62% 2.26G/3.64G [00:24<00:36, 37.5MB/s]
#
# model-00001-of-00002.safetensors:  43% 2.14G/4.96G [00:23<01:12, 38.7MB/s]
# model-00002-of-00002.safetensors:  63% 2.28G/3.64G [00:24<00:32, 41.9MB/s]
#
# model-00001-of-00002.safetensors:  44% 2.16G/4.96G [00:23<00:57, 49.0MB/s]
# model-00002-of-00002.safetensors:  63% 2.30G/3.64G [00:24<00:24, 53.9MB/s]
#
# model-00001-of-00002.safetensors:  44% 2.18G/4.96G [00:24<00:44, 63.0MB/s]
# model-00002-of-00002.safetensors:  64% 2.32G/3.64G [00:24<00:18, 69.6MB/s]
#
# model-00001-of-00002.safetensors:  44% 2.20G/4.96G [00:24<00:35, 78.6MB/s]
# model-00002-of-00002.safetensors:  64% 2.34G/3.64G [00:24<00:14, 86.8MB/s]
#
# model-00001-of-00002.safetensors:  45% 2.22G/4.96G [00:24<00:28, 95.0MB/s]
# model-00002-of-00002.safetensors:  65% 2.36G/3.64G [00:24<00:12, 106MB/s]
#
# model-00001-of-00002.safetensors:  45% 2.24G/4.96G [00:24<00:24, 111MB/s]
# model-00002-of-00002.safetensors:  65% 2.38G/3.64G [00:25<00:10, 124MB/s]
#
# model-00001-of-00002.safetensors:  46% 2.28G/4.96G [00:24<00:19, 141MB/s]
# model-00002-of-00002.safetensors:  66% 2.41G/3.64G [00:25<00:08, 150MB/s]
#
# model-00001-of-00002.safetensors:  46% 2.31G/4.96G [00:24<00:15, 168MB/s]
# model-00002-of-00002.safetensors:  67% 2.44G/3.64G [00:27<00:34, 34.3MB/s]
# model-00002-of-00002.safetensors:  68% 2.47G/3.64G [00:27<00:23, 48.8MB/s]
# model-00002-of-00002.safetensors:  69% 2.51G/3.64G [00:27<00:16, 67.5MB/s]
#
# model-00001-of-00002.safetensors:  47% 2.34G/4.96G [00:27<01:17, 33.8MB/s]
# model-00002-of-00002.safetensors:  70% 2.54G/3.64G [00:27<00:13, 84.0MB/s]
#
# model-00001-of-00002.safetensors:  48% 2.36G/4.96G [00:27<01:01, 42.0MB/s]
# model-00002-of-00002.safetensors:  70% 2.56G/3.64G [00:27<00:11, 97.0MB/s]
#
# model-00001-of-00002.safetensors:  48% 2.39G/4.96G [00:27<00:43, 58.5MB/s]
# model-00002-of-00002.safetensors:  71% 2.58G/3.64G [00:31<00:53, 19.8MB/s]
#
# model-00001-of-00002.safetensors:  49% 2.41G/4.96G [00:30<02:20, 18.2MB/s]
# model-00002-of-00002.safetensors:  72% 2.61G/3.64G [00:31<00:35, 28.8MB/s]
#
# model-00001-of-00002.safetensors:  49% 2.43G/4.96G [00:30<01:46, 23.8MB/s]
# model-00002-of-00002.safetensors:  72% 2.63G/3.64G [00:31<00:27, 36.4MB/s]
#
# model-00001-of-00002.safetensors:  49% 2.45G/4.96G [00:31<01:21, 30.7MB/s]
# model-00002-of-00002.safetensors:  73% 2.65G/3.64G [00:31<00:21, 45.1MB/s]
#
# model-00001-of-00002.safetensors:  50% 2.47G/4.96G [00:31<01:03, 39.0MB/s]
# model-00002-of-00002.safetensors:  73% 2.67G/3.64G [00:32<00:17, 53.9MB/s]
#
# model-00001-of-00002.safetensors:  50% 2.50G/4.96G [00:31<00:50, 48.9MB/s]
#
# model-00001-of-00002.safetensors:  51% 2.52G/4.96G [00:31<00:39, 61.9MB/s]
# model-00002-of-00002.safetensors:  74% 2.69G/3.64G [00:32<00:14, 65.3MB/s]
# model-00002-of-00002.safetensors:  75% 2.72G/3.64G [00:32<00:11, 78.4MB/s]
#
# model-00001-of-00002.safetensors:  51% 2.54G/4.96G [00:31<00:32, 73.5MB/s]
#
# model-00001-of-00002.safetensors:  52% 2.56G/4.96G [00:31<00:27, 88.4MB/s]
# model-00002-of-00002.safetensors:  75% 2.74G/3.64G [00:32<00:10, 89.5MB/s]
#
# model-00001-of-00002.safetensors:  52% 2.58G/4.96G [00:31<00:22, 105MB/s]
# model-00002-of-00002.safetensors:  76% 2.76G/3.64G [00:32<00:08, 104MB/s]
#
# model-00001-of-00002.safetensors:  52% 2.60G/4.96G [00:32<00:19, 119MB/s]
# model-00002-of-00002.safetensors:  76% 2.78G/3.64G [00:32<00:07, 108MB/s]
#
# model-00001-of-00002.safetensors:  53% 2.62G/4.96G [00:32<00:20, 116MB/s]
# model-00002-of-00002.safetensors:  77% 2.80G/3.64G [00:36<00:52, 16.0MB/s]
# model-00002-of-00002.safetensors:  77% 2.81G/3.64G [00:37<00:54, 15.3MB/s]
# model-00002-of-00002.safetensors:  78% 2.84G/3.64G [00:37<00:30, 25.8MB/s]
# model-00002-of-00002.safetensors:  79% 2.88G/3.64G [00:37<00:17, 43.9MB/s]
#
# model-00001-of-00002.safetensors:  53% 2.64G/4.96G [00:37<02:57, 13.1MB/s]
# model-00002-of-00002.safetensors:  80% 2.90G/3.64G [00:37<00:13, 53.0MB/s]
#
# model-00001-of-00002.safetensors:  54% 2.66G/4.96G [00:37<02:08, 17.9MB/s]
#
# model-00001-of-00002.safetensors:  54% 2.68G/4.96G [00:37<01:33, 24.5MB/s]
# model-00002-of-00002.safetensors:  80% 2.93G/3.64G [00:38<00:11, 61.3MB/s]
#
# model-00001-of-00002.safetensors:  55% 2.71G/4.96G [00:37<01:09, 32.7MB/s]
# model-00002-of-00002.safetensors:  81% 2.96G/3.64G [00:38<00:08, 82.3MB/s]
#
# model-00001-of-00002.safetensors:  55% 2.74G/4.96G [00:37<00:45, 49.0MB/s]
# model-00002-of-00002.safetensors:  82% 2.99G/3.64G [00:38<00:06, 101MB/s]
#
# model-00001-of-00002.safetensors:  56% 2.76G/4.96G [00:37<00:38, 56.9MB/s]
# model-00002-of-00002.safetensors:  83% 3.01G/3.64G [00:38<00:06, 101MB/s]
#
# model-00001-of-00002.safetensors:  56% 2.78G/4.96G [00:38<00:33, 64.9MB/s]
# model-00002-of-00002.safetensors:  83% 3.03G/3.64G [00:38<00:05, 103MB/s]
#
# model-00001-of-00002.safetensors:  56% 2.80G/4.96G [00:38<00:29, 72.3MB/s]
# model-00002-of-00002.safetensors:  84% 3.05G/3.64G [00:39<00:06, 97.2MB/s]
#
# model-00001-of-00002.safetensors:  57% 2.82G/4.96G [00:42<02:35, 13.7MB/s]
# model-00002-of-00002.safetensors:  84% 3.07G/3.64G [00:43<00:38, 14.6MB/s]
#
# model-00001-of-00002.safetensors:  57% 2.83G/4.96G [00:43<02:14, 15.8MB/s]
# model-00002-of-00002.safetensors:  85% 3.09G/3.64G [00:43<00:27, 19.7MB/s]
#
# model-00001-of-00002.safetensors:  57% 2.85G/4.96G [00:43<01:33, 22.6MB/s]
# model-00002-of-00002.safetensors:  86% 3.11G/3.64G [00:43<00:19, 26.7MB/s]
#
# model-00001-of-00002.safetensors:  58% 2.87G/4.96G [00:43<01:07, 30.9MB/s]
# model-00002-of-00002.safetensors:  86% 3.14G/3.64G [00:44<00:14, 34.0MB/s]
#
# model-00001-of-00002.safetensors:  58% 2.89G/4.96G [00:43<00:51, 40.4MB/s]
# model-00002-of-00002.safetensors:  87% 3.16G/3.64G [00:44<00:11, 43.1MB/s]
#
# model-00001-of-00002.safetensors:  59% 2.92G/4.96G [00:43<00:40, 50.8MB/s]
# model-00002-of-00002.safetensors:  87% 3.18G/3.64G [00:44<00:08, 54.7MB/s]
#
# model-00001-of-00002.safetensors:  59% 2.94G/4.96G [00:43<00:30, 65.8MB/s]
#
# model-00001-of-00002.safetensors:  60% 2.96G/4.96G [00:43<00:24, 82.2MB/s]
# model-00002-of-00002.safetensors:  88% 3.20G/3.64G [00:44<00:06, 67.4MB/s]
#
# model-00001-of-00002.safetensors:  60% 2.98G/4.96G [00:44<00:20, 96.1MB/s]
# model-00002-of-00002.safetensors:  88% 3.22G/3.64G [00:44<00:05, 81.1MB/s]
#
# model-00001-of-00002.safetensors:  60% 3.00G/4.96G [00:44<00:19, 98.2MB/s]
# model-00002-of-00002.safetensors:  89% 3.24G/3.64G [00:44<00:04, 82.9MB/s]
#
# model-00001-of-00002.safetensors:  61% 3.02G/4.96G [00:44<00:24, 80.1MB/s]
# model-00002-of-00002.safetensors:  90% 3.26G/3.64G [00:45<00:05, 69.0MB/s]
# model-00002-of-00002.safetensors:  90% 3.27G/3.64G [00:49<00:31, 11.5MB/s]
# model-00002-of-00002.safetensors:  91% 3.30G/3.64G [00:49<00:17, 19.4MB/s]
#
# model-00001-of-00002.safetensors:  61% 3.04G/4.96G [00:49<02:30, 12.8MB/s]
# model-00002-of-00002.safetensors:  91% 3.32G/3.64G [00:50<00:12, 26.1MB/s]
#
# model-00001-of-00002.safetensors:  62% 3.06G/4.96G [00:49<01:46, 17.8MB/s]
# model-00002-of-00002.safetensors:  92% 3.34G/3.64G [00:50<00:08, 34.8MB/s]
#
# model-00001-of-00002.safetensors:  62% 3.08G/4.96G [00:49<01:16, 24.5MB/s]
# model-00002-of-00002.safetensors:  92% 3.37G/3.64G [00:50<00:06, 45.1MB/s]
#
# model-00001-of-00002.safetensors:  63% 3.10G/4.96G [00:49<00:57, 32.4MB/s]
# model-00002-of-00002.safetensors:  93% 3.39G/3.64G [00:50<00:04, 57.2MB/s]
#
# model-00001-of-00002.safetensors:  63% 3.14G/4.96G [00:50<00:37, 48.5MB/s]
# model-00002-of-00002.safetensors:  94% 3.41G/3.64G [00:50<00:03, 71.1MB/s]
#
# model-00001-of-00002.safetensors:  64% 3.16G/4.96G [00:50<00:30, 59.6MB/s]
# model-00002-of-00002.safetensors:  94% 3.43G/3.64G [00:50<00:02, 81.9MB/s]
#
# model-00001-of-00002.safetensors:  64% 3.18G/4.96G [00:50<00:26, 68.6MB/s]
# model-00002-of-00002.safetensors:  95% 3.45G/3.64G [00:50<00:02, 89.6MB/s]
#
# model-00001-of-00002.safetensors:  64% 3.20G/4.96G [00:50<00:25, 69.8MB/s]
# model-00002-of-00002.safetensors:  95% 3.47G/3.64G [00:51<00:02, 82.5MB/s]
#
# model-00001-of-00002.safetensors:  65% 3.22G/4.96G [00:55<02:12, 13.2MB/s]
# model-00002-of-00002.safetensors:  96% 3.49G/3.64G [00:55<00:11, 13.2MB/s]
#
# model-00001-of-00002.safetensors:  65% 3.24G/4.96G [00:55<01:34, 18.1MB/s]
# model-00002-of-00002.safetensors:  97% 3.51G/3.64G [00:56<00:06, 18.2MB/s]
#
# model-00001-of-00002.safetensors:  66% 3.26G/4.96G [00:55<01:09, 24.6MB/s]
# model-00002-of-00002.safetensors:  97% 3.53G/3.64G [00:56<00:04, 24.9MB/s]
#
# model-00001-of-00002.safetensors:  66% 3.28G/4.96G [00:55<00:51, 32.3MB/s]
# model-00002-of-00002.safetensors:  98% 3.55G/3.64G [00:56<00:02, 32.9MB/s]
#
# model-00001-of-00002.safetensors:  67% 3.30G/4.96G [00:55<00:40, 41.3MB/s]
# model-00002-of-00002.safetensors:  98% 3.58G/3.64G [00:56<00:01, 41.6MB/s]
#
# model-00001-of-00002.safetensors:  67% 3.32G/4.96G [00:56<00:31, 52.2MB/s]
# model-00002-of-00002.safetensors:  99% 3.60G/3.64G [00:56<00:00, 52.5MB/s]
#
# model-00001-of-00002.safetensors:  67% 3.34G/4.96G [00:56<00:24, 66.1MB/s]
# model-00002-of-00002.safetensors:  99% 3.62G/3.64G [00:56<00:00, 65.6MB/s]
#
# model-00001-of-00002.safetensors:  68% 3.37G/4.96G [00:59<01:30, 17.6MB/s]
#
# model-00001-of-00002.safetensors:  68% 3.40G/4.96G [00:59<00:56, 27.8MB/s]
#
# model-00001-of-00002.safetensors:  69% 3.43G/4.96G [00:59<00:37, 41.3MB/s]
# model-00002-of-00002.safetensors: 100% 3.64G/3.64G [01:00<00:00, 60.3MB/s]
#
#
# model-00001-of-00002.safetensors:  70% 3.46G/4.96G [00:59<00:25, 58.1MB/s]
#
# model-00001-of-00002.safetensors:  70% 3.49G/4.96G [00:59<00:18, 77.4MB/s]
#
# model-00001-of-00002.safetensors:  71% 3.52G/4.96G [01:00<00:14, 98.7MB/s]
#
# model-00001-of-00002.safetensors:  72% 3.55G/4.96G [01:00<00:11, 124MB/s]
#
# model-00001-of-00002.safetensors:  72% 3.59G/4.96G [01:00<00:09, 147MB/s]
#
# model-00001-of-00002.safetensors:  73% 3.62G/4.96G [01:00<00:07, 172MB/s]
#
# model-00001-of-00002.safetensors:  74% 3.65G/4.96G [01:00<00:06, 194MB/s]
#
# model-00001-of-00002.safetensors:  74% 3.68G/4.96G [01:00<00:05, 214MB/s]
#
# model-00001-of-00002.safetensors:  75% 3.71G/4.96G [01:00<00:05, 226MB/s]
#
# model-00001-of-00002.safetensors:  75% 3.74G/4.96G [01:00<00:05, 223MB/s]
#
# model-00001-of-00002.safetensors:  76% 3.77G/4.96G [01:01<00:04, 241MB/s]
#
# model-00001-of-00002.safetensors:  77% 3.81G/4.96G [01:01<00:04, 237MB/s]
#
# model-00001-of-00002.safetensors:  77% 3.84G/4.96G [01:01<00:04, 242MB/s]
#
# model-00001-of-00002.safetensors:  78% 3.87G/4.96G [01:01<00:04, 242MB/s]
#
# model-00001-of-00002.safetensors:  79% 3.90G/4.96G [01:01<00:04, 242MB/s]
#
# model-00001-of-00002.safetensors:  79% 3.93G/4.96G [01:01<00:04, 246MB/s]
#
# model-00001-of-00002.safetensors:  80% 3.96G/4.96G [01:01<00:03, 256MB/s]
#
# model-00001-of-00002.safetensors:  81% 4.00G/4.96G [01:01<00:03, 259MB/s]
#
# model-00001-of-00002.safetensors:  81% 4.03G/4.96G [01:02<00:03, 253MB/s]
#
# model-00001-of-00002.safetensors:  82% 4.06G/4.96G [01:02<00:03, 251MB/s]
#
# model-00001-of-00002.safetensors:  82% 4.09G/4.96G [01:02<00:03, 257MB/s]
#
# model-00001-of-00002.safetensors:  83% 4.12G/4.96G [01:02<00:03, 258MB/s]
#
# model-00001-of-00002.safetensors:  84% 4.15G/4.96G [01:02<00:03, 238MB/s]
#
# model-00001-of-00002.safetensors:  84% 4.18G/4.96G [01:02<00:03, 237MB/s]
#
# model-00001-of-00002.safetensors:  85% 4.22G/4.96G [01:02<00:02, 250MB/s]
#
# model-00001-of-00002.safetensors:  86% 4.25G/4.96G [01:02<00:02, 256MB/s]
#
# model-00001-of-00002.safetensors:  86% 4.28G/4.96G [01:03<00:02, 260MB/s]
#
# model-00001-of-00002.safetensors:  87% 4.31G/4.96G [01:03<00:02, 255MB/s]
#
# model-00001-of-00002.safetensors:  88% 4.34G/4.96G [01:03<00:02, 259MB/s]
#
# model-00001-of-00002.safetensors:  88% 4.37G/4.96G [01:03<00:02, 265MB/s]
#
# model-00001-of-00002.safetensors:  89% 4.40G/4.96G [01:03<00:02, 255MB/s]
#
# model-00001-of-00002.safetensors:  89% 4.44G/4.96G [01:03<00:02, 260MB/s]
#
# model-00001-of-00002.safetensors:  90% 4.47G/4.96G [01:03<00:02, 219MB/s]
#
# model-00001-of-00002.safetensors:  91% 4.50G/4.96G [01:03<00:01, 235MB/s]
#
# model-00001-of-00002.safetensors:  91% 4.53G/4.96G [01:04<00:01, 231MB/s]
#
# model-00001-of-00002.safetensors:  92% 4.56G/4.96G [01:04<00:01, 236MB/s]
#
# model-00001-of-00002.safetensors:  93% 4.59G/4.96G [01:04<00:01, 249MB/s]
#
# model-00001-of-00002.safetensors:  93% 4.62G/4.96G [01:04<00:01, 251MB/s]
#
# model-00001-of-00002.safetensors:  94% 4.66G/4.96G [01:04<00:01, 254MB/s]
#
# model-00001-of-00002.safetensors:  94% 4.69G/4.96G [01:04<00:01, 260MB/s]
#
# model-00001-of-00002.safetensors:  95% 4.72G/4.96G [01:04<00:00, 256MB/s]
#
# model-00001-of-00002.safetensors:  96% 4.75G/4.96G [01:04<00:00, 261MB/s]
#
# model-00001-of-00002.safetensors:  96% 4.78G/4.96G [01:05<00:00, 265MB/s]
#
# model-00001-of-00002.safetensors:  97% 4.81G/4.96G [01:05<00:00, 260MB/s]
#
# model-00001-of-00002.safetensors:  98% 4.84G/4.96G [01:05<00:00, 270MB/s]
#
# model-00001-of-00002.safetensors:  98% 4.88G/4.96G [01:05<00:00, 275MB/s]
#
# model-00001-of-00002.safetensors:  99% 4.91G/4.96G [01:05<00:00, 278MB/s]
#
# model-00001-of-00002.safetensors: 100% 4.96G/4.96G [01:05<00:00, 75.6MB/s]
# Fetching 2 files: 100% 2/2 [01:06<00:00, 33.20s/it]
# Loading checkpoint shards: 100% 2/2 [00:01<00:00,  1.96it/s]
# generation_config.json: 100% 215/215 [00:00<00:00, 1.47MB/s]
# tokenizer_config.json: 100% 1.16M/1.16M [00:00<00:00, 1.56MB/s]
# tokenizer.model: 100% 4.69M/4.69M [00:00<00:00, 65.0MB/s]
# tokenizer.json: 100% 33.4M/33.4M [00:00<00:00, 264MB/s]
# added_tokens.json: 100% 35.0/35.0 [00:00<00:00, 279kB/s]
# special_tokens_map.json: 100% 662/662 [00:00<00:00, 5.06MB/s]
# Device set to use cuda
# 2025-04-21 17:50:56.839 Examining the path of torch.classes raised:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/web/bootstrap.py", line 347, in run
#     if asyncio.get_running_loop().is_running():
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: no running event loop
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/watcher/local_sources_watcher.py", line 217, in get_module_paths
#     potential_paths = extract_paths(module)
#                       ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/watcher/local_sources_watcher.py", line 210, in <lambda>
#     lambda m: list(m.__path__._path),
#                    ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/_classes.py", line 13, in __getattr__
#     proxy = torch._C._get_custom_class_python_wrapper(self.name, attr)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: Tried to instantiate class '__path__._path', but it does not exist! Ensure that it is registered via torch::class_
# NLTK Punkt data checked/downloaded.
# Database 'chat_feedback.db' initialized successfully.
# NLTK Punkt data checked/downloaded.
# Database 'chat_feedback.db' initialized successfully.
# NLTK Punkt data checked/downloaded.
# Database 'chat_feedback.db' initialized successfully.
# NLTK Punkt data checked/downloaded.
# Database 'chat_feedback.db' initialized successfully.
# Generated response in 46.43s
# NLTK Punkt data checked/downloaded.
# Database 'chat_feedback.db' initialized successfully.
#   Stopping...
#   Stopping...
# Exception ignored in: <module 'threading' from '/usr/lib/python3.11/threading.py'>
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/threading.py", line 1560, in _shutdown
#     atexit_call()
#   File "/usr/lib/python3.11/concurrent/futures/thread.py", line 27, in _python_exit
#     items = list(_threads_queues.items())
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/weakref.py", line 464, in items
#     key = wr()
#           ^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/web/bootstrap.py", line 44, in signal_handler
#     server.stop()
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/web/server/server.py", line 470, in stop
#     self._runtime.stop()
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/runtime.py", line 337, in stop
#     async_objs.eventloop.call_soon_threadsafe(stop_on_eventloop)
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 807, in call_soon_threadsafe
#     self._check_closed()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 520, in _check_closed
#     raise RuntimeError('Event loop is closed')
# RuntimeError: Event loop is closed

# %% [markdown]
# アプリケーションの機能としては、チャット機能や履歴閲覧があります。
#
# これらの機能を実現するためには、StreamlitによるUI部分だけではなく、SQLiteを使用したチャット履歴の保存やLLMのモデルを呼び出した推論などの処理を組み合わせることで実現しています。
#
# - **`app.py`**: アプリケーションのエントリーポイント。チャット機能、履歴閲覧、サンプルデータ管理のUIを提供します。
# - **`ui.py`**: チャットページや履歴閲覧ページなど、アプリケーションのUIロジックを管理します。
# - **`llm.py`**: LLMモデルのロードとテキスト生成を行うモジュール。
# - **`database.py`**: SQLiteデータベースを使用してチャット履歴やフィードバックを保存・管理します。
# - **`metrics.py`**: BLEUスコアやコサイン類似度など、回答の評価指標を計算するモジュール。
# - **`data.py`**: サンプルデータの作成やデータベースの初期化を行うモジュール。
# - **`config.py`**: アプリケーションの設定（モデル名やデータベースファイル名）を管理します。
# - **`requirements.txt`**: このアプリケーションを実行するために必要なPythonパッケージ。

# %% [markdown]
# 後片付けとして、使う必要のないngrokのトンネルを削除します。

# %%
from pyngrok import ngrok
ngrok.kill()
